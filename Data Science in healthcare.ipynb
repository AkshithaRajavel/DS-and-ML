# %%
from random import randint
import pandas as pd

# %%
types=['Bariatric Surgery',
 'Breast Surgery',
 'Colon & Rectal Surgery',
 'Endocrine Surgery',
 'General Surgery',
 'Gynecological Surgery',
 'Hand Surgery',
 'Head & Neck Surgery']
types
# Out:
# ['Bariatric Surgery',
#  'Breast Surgery',
#  'Colon & Rectal Surgery',
#  'Endocrine Surgery',
#  'General Surgery',
#  'Gynecological Surgery',
#  'Hand Surgery',
#  'Head & Neck Surgery']

# %%
dataset = pd.read_csv("/content/insurance.csv")

# %%
n=1338
surgery=[]
for i in range(1338):
  surgery+=[types[randint(0,len(types)-1)]]
surgery=pd.Series(surgery)
dataset['surgery']=surgery
dataset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#                   surgery
# 0     Head & Neck Surgery
# 1            Hand Surgery
# 2         General Surgery
# 3     Head & Neck Surgery
# 4  Colon & Rectal Surgery
